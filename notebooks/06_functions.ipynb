# %% [markdown]
# # Functions

# %%
# The print function
print("Hello World")
# Out:
# Hello World

# %%
def my_function():
    print("Hello Shai")
    print("You shall succeed")
    
my_function()
# Out:
# Hello Shai
# You shall succeed
